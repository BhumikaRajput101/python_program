# %% [markdown]
# Iterators

# %%
mylist=[1,3,4,2,5,6,7]
for i in mylist:
    print(i)

# %%
type(mylist)

# %%
print(mylist)

# %%
iterator =iter(mylist)
print(type(iterator))

# %%
iterator

# %%
next(iterator)

# %%
iterator =iter(mylist)
try:
    print(next(iterator))
except StopIteration:
    print("there is no more element")

# %% [markdown]
# Generators

# %%
def square(n):
    for i in range(3):
        yield i**2
square(3)

# %%
for i in square(3):
    print(i)

# %%
a= square(3)

# %%
for i in square(3):
    print(i)

# %%
a= square(3)

# %%
next(a)

# %%
def mygenerator():
    yield 1
    yield 2
    yield 3

# %%
gen=mygenerator()
gen

# %%
next(gen)

# %%
# pratical : reading large file
def readfile(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line

# %%
file_path= 'mynewfile.txt'
for line in readfile(file_path):
    print(line.strip())
