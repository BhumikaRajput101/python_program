# %% [markdown]
# Exception Handling

# %%
try:
    a=b
except:
    print("the value of b is not define")
print(b)

# %%
try:
    a=b
except NameError as ex:
    print(ex)

# %%
try:
    a=1/0
    c=d
except ZeroDivisionError as ex:
    print(ex)
    print("enter the value geater than 0")
except NameError as ex1:

    print(ex1)

# %%
#handle value  error
try:
    a=int(input('enter a number '))
except ValueError as ex:
    print(ex)

# %%
#try except else
try:
    a=int(input('enter a number '))
    result =10/num
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex1:
    print(ex1)
else:
    print(f"the result is{result}")

# %%
#try except else finally
try:
    a=int(input('enter a number '))
    result =10/num
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex1:
    print(ex1)
else:
    print(f"the result is{result}")
finally:
    print("execution complete")

# %%
### file handling and error exception
try:
    file=open("exme.txt","r")
    content=file.read()
    print(content)
except FileNotFoundError :
    print('the file does not exist')
finally: 
    if 'file' in locals() and not file.closed():
        file.closed()
